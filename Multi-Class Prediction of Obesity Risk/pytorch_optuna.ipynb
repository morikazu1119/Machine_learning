# %% [markdown]
# ## Import library

# %%
import random
import os

from xgboost import XGBClassifier
from lightgbm import log_evaluation, early_stopping, LGBMClassifier
from catboost import CatBoostClassifier

from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn import set_config
from sklearn.base import clone
from sklearn.model_selection import StratifiedKFold, cross_val_predict, train_test_split
from sklearn.inspection import permutation_importance
from sklearn.utils import shuffle
from sklearn.preprocessing import FunctionTransformer, StandardScaler, MinMaxScaler, RobustScaler, OneHotEncoder, LabelEncoder
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score , classification_report

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import optuna

import random
import os

import torch
import torch.nn as nn
from torch.utils.data import Dataset,DataLoader
from torch.utils.data import TensorDataset
import torchvision
import torchvision.transforms as transforms
from torch.optim import Adam

# %% [markdown]
# ## Config

# %%
class CFG:
    def __init__(self):

        self.seed=777
        self.epochs=200
        self.batch_size=2048
        self.learning_rate=0.0007
        self.input_class=None
        self.output_class=7

        self.device=torch.device("cuda:0"if torch.cuda.is_available() else "cpu")

        self.train=pd.read_csv("data/train.csv")
        self.test=pd.read_csv("data/test.csv")
        #mainは他のデータセット参照
        self.main=pd.read_csv("data/ObesityDataSet.csv")

        self.class_mapping = {
            'Overweight_Level_II': 0,
            'Normal_Weight': 1,
            'Insufficient_Weight': 2,
            'Obesity_Type_III': 3,
            'Obesity_Type_II': 4,
            'Overweight_Level_I': 5,
            'Obesity_Type_I': 6
        }
        
        self.freq_mapping={
            'no': 0,
            'Always': 3,
            'Frequently': 2,
            'Sometimes': 1
        }

        self.transport_mapping = {
            'Bike': 2,
            'Walking': 2,
            'Public_Transportation': 1,
            'Automobile': 0,
            'Motorbike': 0,
        }

config=CFG()

def torch_seed(seed):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.use_deterministic_algorithms=True
    torch.backends.cudnn.deterministic=True
    torch.backends.cudnn.benchmark=True

torch_seed(config.seed)

# %% [markdown]
# ## Load data

# %% [markdown]
# - id : 各個人の一意の識別子
# - 性別 : 個人が男性か女性かを示します。
# - 年齢 : 個人の年齢
# - 身長 : センチメートル単位の個人の身長
# - 体重 : 個人の体重 (キログラム)
# - family_history_with_overweight : 個人に肥満の家族歴があるかどうかを示します。
# - FAVC : 高カロリー食品の摂取頻度
# - FCVC : 野菜の摂取頻度
# - NCP : 主食の数
# - CAEC : 間食の摂取
# - SMOKE : 喫煙状態
# - CH2O : 1 日あたりの水の消費量
# - SCC : カロリー消費モニタリング
# - FAF : 身体活動の頻度
# - TUE : テクノロジーデバイスの使用時間
# - CALC : アルコールの摂取量
# - MTRANS : 利用した交通機関

# %% [markdown]
# # Make train and test data

# %%
train=config.train.drop("id",axis=1)
test_X=config.test.drop("id",axis=1)
main=config.main
print(train.shape,main.shape)

train=pd.concat([train,main],axis=0)
train.shape
print(train.shape)
# Out:
# (20758, 17) (2111, 17)
# (22869, 17)

# %%
print(train.duplicated().sum())
train = train.drop_duplicates()
# Out:
# 24

# %%
data=train.copy()
data
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0       Male  24.443011  1.699998   81.669950                            yes
# 1     Female  18.000000  1.560000   57.000000                            yes
# 2     Female  18.000000  1.711460   50.165754                            yes
# 3     Female  20.952737  1.710730  131.274851                            yes
# 4       Male  31.641081  1.914186   93.798055                            yes
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
#      FAVC      FCVC       NCP        CAEC SMOKE      CH2O SCC       FAF  \
# 0     yes  2.000000  2.983297   Sometimes    no  2.763573  no  0.000000
# 1     yes  2.000000  3.000000  Frequently    no  2.000000  no  1.000000
# 2     yes  1.880534  1.411685   Sometimes    no  1.910378  no  0.866045
# 3     yes  3.000000  3.000000   Sometimes    no  1.674061  no  1.467863
# 4     yes  2.679664  1.971472   Sometimes    no  1.979848  no  1.967973
# ...   ...       ...       ...         ...   ...       ...  ..       ...
# 2106  yes  3.000000  3.000000   Sometimes    no  1.728139  no  1.676269
# 2107  yes  3.000000  3.000000   Sometimes    no  2.005130  no  1.341390
# 2108  yes  3.000000  3.000000   Sometimes    no  2.054193  no  1.414209
# 2109  yes  3.000000  3.000000   Sometimes    no  2.852339  no  1.139107
# 2110  yes  3.000000  3.000000   Sometimes    no  2.863513  no  1.026452
#
#            TUE       CALC                 MTRANS           NObeyesdad
# 0     0.976473  Sometimes  Public_Transportation  Overweight_Level_II
# 1     1.000000         no             Automobile        Normal_Weight
# 2     1.673584         no  Public_Transportation  Insufficient_Weight
# 3     0.780199  Sometimes  Public_Transportation     Obesity_Type_III
# 4     0.931721  Sometimes  Public_Transportation  Overweight_Level_II
# ...        ...        ...                    ...                  ...
# 2106  0.906247  Sometimes  Public_Transportation     Obesity_Type_III
# 2107  0.599270  Sometimes  Public_Transportation     Obesity_Type_III
# 2108  0.646288  Sometimes  Public_Transportation     Obesity_Type_III
# 2109  0.586035  Sometimes  Public_Transportation     Obesity_Type_III
# 2110  0.714137  Sometimes  Public_Transportation     Obesity_Type_III
#
# [22845 rows x 17 columns]

# %%
num=data.select_dtypes(include=["int64","float64"]).columns
col=data.select_dtypes(include=["object"]).columns
print(num)
print(col)
# Out:
# Index(['Age', 'Height', 'Weight', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE'], dtype='object')
# Index(['Gender', 'family_history_with_overweight', 'FAVC', 'CAEC', 'SMOKE',
#        'SCC', 'CALC', 'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %% [markdown]
# 数値以外の列のユニークな変数を確認

# %%
for col in data:
    if data[col].dtype==object:
        unique=data[col].unique()
        print(f"{col} : {unique}")
# Out:
# Gender : ['Male' 'Female']
# family_history_with_overweight : ['yes' 'no']
# FAVC : ['yes' 'no']
# CAEC : ['Sometimes' 'Frequently' 'no' 'Always']
# SMOKE : ['no' 'yes']
# SCC : ['no' 'yes']
# CALC : ['Sometimes' 'no' 'Frequently' 'Always']
# MTRANS : ['Public_Transportation' 'Automobile' 'Walking' 'Motorbike' 'Bike']
# NObeyesdad : ['Overweight_Level_II' 'Normal_Weight' 'Insufficient_Weight'
#  'Obesity_Type_III' 'Obesity_Type_II' 'Overweight_Level_I'
#  'Obesity_Type_I']

# %% [markdown]
# オブジェクト -> 数値

# %%
def X_encode(X):
    X["Gender"]=X["Gender"].apply(lambda x:1 if x=="Male" else 0)
    X["family_history_with_overweight"]=X["family_history_with_overweight"].apply(lambda x:1 if x=="yes" else 0)
    X["FAVC"]=X["FAVC"].apply(lambda x:1 if x=="yes" else 0)
    X["SMOKE"]=X["SMOKE"].apply(lambda x:1 if x=="yes" else 0)
    X["SCC"]=X["SCC"].apply(lambda x:1 if x=="yes" else 0)
    X["CAEC"]=X["CAEC"].map(config.freq_mapping)
    X["CALC"]=X["CALC"].map(config.freq_mapping)
    X["MTRANS"]=X["MTRANS"].map(config.transport_mapping)
    X["NObeyesdad"]=X["NObeyesdad"].map(config.class_mapping).astype(float)
    return X

data=X_encode(data)
data.dtypes
# Out:
# Gender                              int64
# Age                               float64
# Height                            float64
# Weight                            float64
# family_history_with_overweight      int64
# FAVC                                int64
# FCVC                              float64
# NCP                               float64
# CAEC                                int64
# SMOKE                               int64
# CH2O                              float64
# SCC                                 int64
# FAF                               float64
# TUE                               float64
# CALC                                int64
# MTRANS                              int64
# NObeyesdad                        float64
# dtype: object

# %%
data
# Out:
#       Gender        Age    Height      Weight  family_history_with_overweight  \
# 0          1  24.443011  1.699998   81.669950                               1
# 1          0  18.000000  1.560000   57.000000                               1
# 2          0  18.000000  1.711460   50.165754                               1
# 3          0  20.952737  1.710730  131.274851                               1
# 4          1  31.641081  1.914186   93.798055                               1
# ...      ...        ...       ...         ...                             ...
# 2106       0  20.976842  1.710730  131.408528                               1
# 2107       0  21.982942  1.748584  133.742943                               1
# 2108       0  22.524036  1.752206  133.689352                               1
# 2109       0  24.361936  1.739450  133.346641                               1
# 2110       0  23.664709  1.738836  133.472641                               1
#
#       FAVC      FCVC       NCP  CAEC  SMOKE      CH2O  SCC       FAF  \
# 0        1  2.000000  2.983297     1      0  2.763573    0  0.000000
# 1        1  2.000000  3.000000     2      0  2.000000    0  1.000000
# 2        1  1.880534  1.411685     1      0  1.910378    0  0.866045
# 3        1  3.000000  3.000000     1      0  1.674061    0  1.467863
# 4        1  2.679664  1.971472     1      0  1.979848    0  1.967973
# ...    ...       ...       ...   ...    ...       ...  ...       ...
# 2106     1  3.000000  3.000000     1      0  1.728139    0  1.676269
# 2107     1  3.000000  3.000000     1      0  2.005130    0  1.341390
# 2108     1  3.000000  3.000000     1      0  2.054193    0  1.414209
# 2109     1  3.000000  3.000000     1      0  2.852339    0  1.139107
# 2110     1  3.000000  3.000000     1      0  2.863513    0  1.026452
#
#            TUE  CALC  MTRANS  NObeyesdad
# 0     0.976473     1       1         0.0
# 1     1.000000     0       0         1.0
# 2     1.673584     0       1         2.0
# 3     0.780199     1       1         3.0
# 4     0.931721     1       1         0.0
# ...        ...   ...     ...         ...
# 2106  0.906247     1       1         3.0
# 2107  0.599270     1       1         3.0
# 2108  0.646288     1       1         3.0
# 2109  0.586035     1       1         3.0
# 2110  0.714137     1       1         3.0
#
# [22845 rows x 17 columns]

# %%
# def feature_eng(df):
#     df['Height_Weight'] = df['Weight'] * df['Height']
#     df['Weight_per_Height'] = df['Weight'] / df['Height']
#     df['Weight_per_Height'] = df['Weight'] / (df['Height')**2]
#     df['Height_per_Weight'] = df['Height'] / df['Weight']
#     df['Weight_per_Age'] = df['Weight'] / df['Age']
#     df['Weight_Age'] = df['Weight'] * df['Age']
#     df['Height_per_Age'] = df['Height'] / df['Age']
#     df['Height_Age'] = df['Height'] * df['Age']
    
#     return df

# %%
X=data.drop("NObeyesdad",axis=1)
y=data["NObeyesdad"]
num = X.select_dtypes(include=['int64', 'float64']).columns
col = X.select_dtypes(include=['object']).columns
print(num)
print(col)
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',
#        'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',
#        'CALC', 'MTRANS'],
#       dtype='object')
# Index([], dtype='object')

# %%
def add_columns(X):
    X["BMI"]=X["Weight"]/(X["Height"]**2)
    X["all_eat"]=X["NCP"]+X["CAEC"]
    X["Active"]=X["FAF"]*2+X["MTRANS"]

add_columns(X)

# %% [markdown]
# int , bool -> float

# %%
X=X.astype(float)
X.dtypes
# Out:
# Gender                            float64
# Age                               float64
# Height                            float64
# Weight                            float64
# family_history_with_overweight    float64
# FAVC                              float64
# FCVC                              float64
# NCP                               float64
# CAEC                              float64
# SMOKE                             float64
# CH2O                              float64
# SCC                               float64
# FAF                               float64
# TUE                               float64
# CALC                              float64
# MTRANS                            float64
# BMI                               float64
# all_eat                           float64
# Active                            float64
# dtype: object

# %%
config.input_class=len(X.columns)
config.input_class
# Out:
# 19

# %% [markdown]
# ## Feature engineering

# %%
#標準化
def norm(row):
    min_val=row.min()
    max_val=row.max()
    return (row-min_val)/(max_val-min_val)

def norm_col(X):
    for col in X:
        X[col]=norm(X[col])

norm_col(X)

# 標準化
# scaler=StandardScaler()
# scaler.fit(X)
# 前者は各列に対しての標準化、後者はデータ全体に対しての標準化

# %%
X.head()
# Out:
#    Gender       Age    Height    Weight  family_history_with_overweight  FAVC  \
# 0     1.0  0.222192  0.471694  0.318432                             1.0   1.0
# 1     0.0  0.085106  0.207547  0.134328                             1.0   1.0
# 2     0.0  0.085106  0.493321  0.083327                             1.0   1.0
# 3     0.0  0.147931  0.491943  0.688618                             1.0   1.0
# 4     1.0  0.375342  0.875823  0.408941                             1.0   1.0
#
#        FCVC       NCP      CAEC  SMOKE      CH2O  SCC       FAF       TUE  \
# 0  0.500000  0.661099  0.333333    0.0  0.881787  0.0  0.000000  0.488237
# 1  0.500000  0.666667  0.666667    0.0  0.500000  0.0  0.333333  0.500000
# 2  0.440267  0.137228  0.333333    0.0  0.455189  0.0  0.288682  0.836792
# 3  1.000000  0.666667  0.333333    0.0  0.337031  0.0  0.489288  0.390099
# 4  0.839832  0.323824  0.333333    0.0  0.489924  0.0  0.655991  0.465861
#
#        CALC  MTRANS       BMI   all_eat    Active
# 0  0.333333     0.5  0.365327  0.497216  0.125000
# 1  0.000000     0.0  0.250503  0.666667  0.250000
# 2  0.000000     0.5  0.101073  0.235281  0.341511
# 3  0.333333     0.5  0.759261  0.500000  0.491966
# 4  0.333333     0.5  0.302178  0.328579  0.616993

# %% [markdown]
# # Find best hyper_param

# %% [markdown]
# # Transfer data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=config.seed)

# %%
print(len(X_train))
print(len(y_train))
print(len(X_test))
print(len(y_test))
# Out:
# 18276
# 18276
# 4569
# 4569

# %%
X_train=torch.FloatTensor(np.array(X_train)).to(config.device)
X_test=torch.FloatTensor(np.array(X_test)).to(config.device)
y_train=torch.LongTensor(np.array(y_train)).to(config.device)
y_test=torch.LongTensor(np.array(y_test)).to(config.device)

# %%
train_dataset=TensorDataset(X_train,y_train)
valid_dataset=TensorDataset(X_test,y_test)
train_dataloader=DataLoader(train_dataset,batch_size=config.batch_size,shuffle=True)
valid_dataloader=DataLoader(valid_dataset,batch_size=config.batch_size,shuffle=True)

batch_iterator = iter(train_dataloader)
inputs, labels = next(batch_iterator)
print(inputs.size())
print(labels.size())
# Out:
# torch.Size([2048, 19])
# torch.Size([2048])

# %% [markdown]
# ## Model

# %% [markdown]
# # Pytorch

# %%
class Model(nn.Module):

    def __init__(self,input_size,output_size,layer1_out,layer2_out,layer3_out,drop_out):
        super().__init__()
        self.layer1=nn.Linear(input_size,layer1_out)
        self.layer2=nn.Linear(layer1_out,layer2_out)
        self.layer3=nn.Linear(layer2_out,layer3_out)
        self.layer4=nn.Linear(layer3_out,output_size)

        self.dropout=nn.Dropout(p=drop_out)
        self.norm1=nn.BatchNorm1d(layer1_out)
        self.norm2=nn.BatchNorm1d(layer2_out)
        self.norm3=nn.BatchNorm1d(layer3_out)

    def forward(self,x):
        x=self.layer1(x)
        #x=self.norm1(x)
        x=nn.ReLU()(x)

        x=self.layer2(x)
        #x=self.norm2(x)
        x=nn.ReLU()(x)
        x=self.dropout(x)

        x=self.layer3(x)
        #x=self.norm3(x)
        x=nn.ReLU()(x)
        x=self.dropout(x)
        
        x=self.layer4(x)
        return x

# %%
def train(model,device,train_dataloader,optimizer):
    criterion=nn.CrossEntropyLoss()

    model.train()
    for idx,(X,y) in enumerate(train_dataloader):
        X,y=X.to(device),y.to(device)
        optimizer.zero_grad()
        pred=model(X)
        loss=criterion(pred,y)
        loss.backward()
        optimizer.step()

def valid(model,device,valid_dataloader):
    model.eval()
    correct=0
    with torch.no_grad():
        for X,y in valid_dataloader:
            X,y=X.to(device),y.to(device)
            pred=model(X)
            pred=pred.max(1, keepdim=True)[1]
            correct+=pred.eq(y.view_as(pred)).sum().item()
    
    return 1-correct/len(valid_dataloader.dataset)

def test(model,device,test_data):
    model.eval()
    with torch.no_grad():
        for X in test_data:
            X=X.to(device)
            pred=model(X)
    return pred

# %%
def objective(trial):

    #batch_size = trial.suggest_int('batch_size', 512, 2048)
    #epochs = trial.suggest_int('epochs', 50, 300)
    learning_rate = trial.suggest_float('learning_rate', 0.0007, 0.001)
    layer1_out = trial.suggest_int('layer1_out', 512, 1024,step=2)
    layer2_out = trial.suggest_int('layer2_out', 128, 512,step=2)
    layer3_out = trial.suggest_int('layer3_out', 64, 128,step=2)
    drop_out = trial.suggest_float("drop_out", 0.1, 0.3,step=0.1)
    #loss_type = trial.suggest_categorical('loss_type', ["Adam", "SGD"])
                                                               
    device=config.device
    model = Model(config.input_class,config.output_class,layer1_out,layer2_out,layer3_out,drop_out).to(device)
    optimizer=Adam(model.parameters(),lr=learning_rate)

    epochs=config.epochs
    for step in range(epochs):
        train(model,device,train_dataloader,optimizer)
        error_rate=valid(model,device,valid_dataloader)
    
    return error_rate

# Create a study object and optimize the objective function
study = optuna.create_study()
study.optimize(objective, n_trials=50)

# Get the best hyperparameters
best_params = study.best_params
print("Best Hyperparameters:", best_params)
# Out:
# [I 2024-02-23 20:09:28,450] A new study created in memory with name: no-name-b90c3c30-09f5-4597-a3b3-db73b435a798
# [I 2024-02-23 20:09:57,723] Trial 0 finished with value: 0.11950098489822714 and parameters: {'learning_rate': 0.0009170384021882243, 'layer1_out': 974, 'layer2_out': 434, 'layer3_out': 96, 'drop_out': 0.2}. Best is trial 0 with value: 0.11950098489822714.
# [I 2024-02-23 20:10:26,738] Trial 1 finished with value: 0.128693368351937 and parameters: {'learning_rate': 0.0009624497094470063, 'layer1_out': 736, 'layer2_out': 402, 'layer3_out': 120, 'drop_out': 0.1}. Best is trial 0 with value: 0.11950098489822714.
# [I 2024-02-23 20:10:55,669] Trial 2 finished with value: 0.11906325235281245 and parameters: {'learning_rate': 0.000932296768253909, 'layer1_out': 866, 'layer2_out': 224, 'layer3_out': 66, 'drop_out': 0.1}. Best is trial 2 with value: 0.11906325235281245.
# [I 2024-02-23 20:11:24,685] Trial 3 finished with value: 0.11993871744364193 and parameters: {'learning_rate': 0.0007874322665011016, 'layer1_out': 790, 'layer2_out': 180, 'layer3_out': 78, 'drop_out': 0.1}. Best is trial 2 with value: 0.11906325235281245.
# [I 2024-02-23 20:11:53,832] Trial 4 finished with value: 0.1249726417159116 and parameters: {'learning_rate': 0.0009159267090450161, 'layer1_out': 1006, 'layer2_out': 498, 'layer3_out': 106, 'drop_out': 0.2}. Best is trial 2 with value: 0.11906325235281245.
# [I 2024-02-23 20:12:22,947] Trial 5 finished with value: 0.11753118844386079 and parameters: {'learning_rate': 0.0007481613111286764, 'layer1_out': 564, 'layer2_out': 416, 'layer3_out': 64, 'drop_out': 0.1}. Best is trial 5 with value: 0.11753118844386079.
# [I 2024-02-23 20:12:52,163] Trial 6 finished with value: 0.1208141825344714 and parameters: {'learning_rate': 0.0008241337383871111, 'layer1_out': 704, 'layer2_out': 448, 'layer3_out': 112, 'drop_out': 0.3}. Best is trial 5 with value: 0.11753118844386079.
# [I 2024-02-23 20:13:21,693] Trial 7 finished with value: 0.11906325235281245 and parameters: {'learning_rate': 0.0008676464607631713, 'layer1_out': 974, 'layer2_out': 302, 'layer3_out': 94, 'drop_out': 0.2}. Best is trial 5 with value: 0.11753118844386079.
# [I 2024-02-23 20:13:51,392] Trial 8 finished with value: 0.11556139198949444 and parameters: {'learning_rate': 0.0007731137492224833, 'layer1_out': 636, 'layer2_out': 284, 'layer3_out': 112, 'drop_out': 0.3}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:14:21,690] Trial 9 finished with value: 0.11578025826220184 and parameters: {'learning_rate': 0.0008213589455733429, 'layer1_out': 544, 'layer2_out': 348, 'layer3_out': 70, 'drop_out': 0.3}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:14:50,756] Trial 10 finished with value: 0.11818778726198298 and parameters: {'learning_rate': 0.0007006125964834776, 'layer1_out': 634, 'layer2_out': 260, 'layer3_out': 128, 'drop_out': 0.3}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:15:20,171] Trial 11 finished with value: 0.1212519150798862 and parameters: {'learning_rate': 0.0008362012919461395, 'layer1_out': 536, 'layer2_out': 338, 'layer3_out': 82, 'drop_out': 0.3}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:15:49,837] Trial 12 finished with value: 0.12278397898883786 and parameters: {'learning_rate': 0.0007707791957656042, 'layer1_out': 630, 'layer2_out': 326, 'layer3_out': 104, 'drop_out': 0.3}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:16:19,223] Trial 13 finished with value: 0.11578025826220184 and parameters: {'learning_rate': 0.000707025727420156, 'layer1_out': 618, 'layer2_out': 358, 'layer3_out': 86, 'drop_out': 0.3}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:16:48,750] Trial 14 finished with value: 0.1173123221711534 and parameters: {'learning_rate': 0.0008682885593223088, 'layer1_out': 520, 'layer2_out': 136, 'layer3_out': 114, 'drop_out': 0.3}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:17:17,972] Trial 15 finished with value: 0.12256511271613046 and parameters: {'learning_rate': 0.0007962118668970434, 'layer1_out': 684, 'layer2_out': 272, 'layer3_out': 74, 'drop_out': 0.2}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:17:47,397] Trial 16 finished with value: 0.1212519150798862 and parameters: {'learning_rate': 0.0007369289039357309, 'layer1_out': 802, 'layer2_out': 376, 'layer3_out': 88, 'drop_out': 0.3}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:18:16,761] Trial 17 finished with value: 0.11775005471656819 and parameters: {'learning_rate': 0.0008207532928304217, 'layer1_out': 588, 'layer2_out': 222, 'layer3_out': 104, 'drop_out': 0.2}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:18:46,577] Trial 18 finished with value: 0.12409717662508213 and parameters: {'learning_rate': 0.0008842958350832378, 'layer1_out': 514, 'layer2_out': 294, 'layer3_out': 128, 'drop_out': 0.3}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:19:16,309] Trial 19 finished with value: 0.11993871744364193 and parameters: {'learning_rate': 0.0009883063134445617, 'layer1_out': 670, 'layer2_out': 488, 'layer3_out': 72, 'drop_out': 0.2}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:19:46,576] Trial 20 finished with value: 0.12059531626176401 and parameters: {'learning_rate': 0.0007548499545106308, 'layer1_out': 846, 'layer2_out': 234, 'layer3_out': 118, 'drop_out': 0.3}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:20:16,419] Trial 21 finished with value: 0.1173123221711534 and parameters: {'learning_rate': 0.000706857511627098, 'layer1_out': 598, 'layer2_out': 346, 'layer3_out': 86, 'drop_out': 0.3}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:20:45,840] Trial 22 finished with value: 0.12015758371634933 and parameters: {'learning_rate': 0.0007252978399825739, 'layer1_out': 624, 'layer2_out': 360, 'layer3_out': 90, 'drop_out': 0.3}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:21:15,355] Trial 23 finished with value: 0.11950098489822714 and parameters: {'learning_rate': 0.0007939214875202839, 'layer1_out': 568, 'layer2_out': 372, 'layer3_out': 70, 'drop_out': 0.3}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:21:44,652] Trial 24 finished with value: 0.11665572335303132 and parameters: {'learning_rate': 0.0007714014830374421, 'layer1_out': 732, 'layer2_out': 310, 'layer3_out': 78, 'drop_out': 0.3}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:22:14,001] Trial 25 finished with value: 0.12234624644342307 and parameters: {'learning_rate': 0.0008091055962266867, 'layer1_out': 652, 'layer2_out': 394, 'layer3_out': 102, 'drop_out': 0.2}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:22:43,116] Trial 26 finished with value: 0.11796892098927558 and parameters: {'learning_rate': 0.0007259248228379066, 'layer1_out': 562, 'layer2_out': 272, 'layer3_out': 84, 'drop_out': 0.3}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:23:12,114] Trial 27 finished with value: 0.12256511271613046 and parameters: {'learning_rate': 0.0008487884219781287, 'layer1_out': 612, 'layer2_out': 452, 'layer3_out': 92, 'drop_out': 0.3}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:23:41,515] Trial 28 finished with value: 0.11753118844386079 and parameters: {'learning_rate': 0.0007684668111096796, 'layer1_out': 716, 'layer2_out': 182, 'layer3_out': 100, 'drop_out': 0.2}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:24:10,611] Trial 29 finished with value: 0.11993871744364193 and parameters: {'learning_rate': 0.0007180313642273512, 'layer1_out': 548, 'layer2_out': 330, 'layer3_out': 96, 'drop_out': 0.3}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:24:40,212] Trial 30 finished with value: 0.11993871744364193 and parameters: {'learning_rate': 0.0007506696010815307, 'layer1_out': 762, 'layer2_out': 422, 'layer3_out': 80, 'drop_out': 0.2}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:25:09,741] Trial 31 finished with value: 0.11862551980739766 and parameters: {'learning_rate': 0.0007699736347770331, 'layer1_out': 670, 'layer2_out': 304, 'layer3_out': 78, 'drop_out': 0.3}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:25:39,290] Trial 32 finished with value: 0.12562924053403368 and parameters: {'learning_rate': 0.0007822102547436965, 'layer1_out': 748, 'layer2_out': 310, 'layer3_out': 76, 'drop_out': 0.3}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:26:08,905] Trial 33 finished with value: 0.12190851389800827 and parameters: {'learning_rate': 0.0008105075020347004, 'layer1_out': 708, 'layer2_out': 356, 'layer3_out': 70, 'drop_out': 0.3}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:26:38,188] Trial 34 finished with value: 0.11665572335303132 and parameters: {'learning_rate': 0.0008400680246569239, 'layer1_out': 586, 'layer2_out': 386, 'layer3_out': 68, 'drop_out': 0.3}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:27:07,451] Trial 35 finished with value: 0.117093455898446 and parameters: {'learning_rate': 0.0009100062617896686, 'layer1_out': 910, 'layer2_out': 254, 'layer3_out': 84, 'drop_out': 0.3}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:27:37,000] Trial 36 finished with value: 0.1208141825344714 and parameters: {'learning_rate': 0.0007379958204636665, 'layer1_out': 824, 'layer2_out': 286, 'layer3_out': 64, 'drop_out': 0.1}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:28:06,715] Trial 37 finished with value: 0.11862551980739766 and parameters: {'learning_rate': 0.0008041809385464668, 'layer1_out': 732, 'layer2_out': 320, 'layer3_out': 110, 'drop_out': 0.3}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:28:36,065] Trial 38 finished with value: 0.11643685708032392 and parameters: {'learning_rate': 0.0007827720354279973, 'layer1_out': 780, 'layer2_out': 406, 'layer3_out': 76, 'drop_out': 0.3}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:29:05,462] Trial 39 finished with value: 0.12322171153425254 and parameters: {'learning_rate': 0.0008224457668673284, 'layer1_out': 898, 'layer2_out': 406, 'layer3_out': 122, 'drop_out': 0.2}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:29:34,546] Trial 40 finished with value: 0.1208141825344714 and parameters: {'learning_rate': 0.000865728262335724, 'layer1_out': 654, 'layer2_out': 446, 'layer3_out': 74, 'drop_out': 0.3}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:30:03,513] Trial 41 finished with value: 0.1214707813525936 and parameters: {'learning_rate': 0.0007751037658213175, 'layer1_out': 796, 'layer2_out': 472, 'layer3_out': 80, 'drop_out': 0.3}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:30:32,740] Trial 42 finished with value: 0.11556139198949444 and parameters: {'learning_rate': 0.0007597615549796771, 'layer1_out': 772, 'layer2_out': 362, 'layer3_out': 76, 'drop_out': 0.3}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:31:02,138] Trial 43 finished with value: 0.11818778726198298 and parameters: {'learning_rate': 0.0007579499396417449, 'layer1_out': 770, 'layer2_out': 422, 'layer3_out': 66, 'drop_out': 0.3}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:31:31,670] Trial 44 finished with value: 0.1210330488071788 and parameters: {'learning_rate': 0.0007850446089560026, 'layer1_out': 868, 'layer2_out': 364, 'layer3_out': 76, 'drop_out': 0.1}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:32:01,290] Trial 45 finished with value: 0.11906325235281245 and parameters: {'learning_rate': 0.0007400695788789473, 'layer1_out': 780, 'layer2_out': 344, 'layer3_out': 98, 'drop_out': 0.3}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:32:30,637] Trial 46 finished with value: 0.11928211862551985 and parameters: {'learning_rate': 0.0007092859850988342, 'layer1_out': 836, 'layer2_out': 388, 'layer3_out': 88, 'drop_out': 0.3}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:32:59,966] Trial 47 finished with value: 0.11621799080761652 and parameters: {'learning_rate': 0.0007959052637477527, 'layer1_out': 694, 'layer2_out': 410, 'layer3_out': 82, 'drop_out': 0.3}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:33:29,197] Trial 48 finished with value: 0.12409717662508213 and parameters: {'learning_rate': 0.0008343047294287096, 'layer1_out': 694, 'layer2_out': 512, 'layer3_out': 108, 'drop_out': 0.3}. Best is trial 8 with value: 0.11556139198949444.
# [I 2024-02-23 20:33:58,796] Trial 49 finished with value: 0.11840665353469026 and parameters: {'learning_rate': 0.000759539823295994, 'layer1_out': 636, 'layer2_out': 340, 'layer3_out': 82, 'drop_out': 0.3}. Best is trial 8 with value: 0.11556139198949444.
# Best Hyperparameters: {'learning_rate': 0.0007731137492224833, 'layer1_out': 636, 'layer2_out': 284, 'layer3_out': 112, 'drop_out': 0.3}

# %%
hyperparameters=best_params

# ファイル名を指定します
file_name = "hypara_pytorch2.txt"

# テキストファイルに書き込みます
with open(file_name, 'w') as file:
    for key, value in hyperparameters.items():
        file.write(f"{key}: {value}\n")

# %% [markdown]
# # Test

# %%
def test_encode(X):
    X["Gender"]=X["Gender"].apply(lambda x:1 if x=="Male" else 0)
    X["family_history_with_overweight"]=X["family_history_with_overweight"].apply(lambda x:1 if x=="yes" else 0)
    X["FAVC"]=X["FAVC"].apply(lambda x:1 if x=="yes" else 0)
    X["SMOKE"]=X["SMOKE"].apply(lambda x:1 if x=="yes" else 0)
    X["SCC"]=X["SCC"].apply(lambda x:1 if x=="yes" else 0)
    X["CAEC"]=X["CAEC"].map(config.freq_mapping)
    X["CALC"]=X["CALC"].map(config.freq_mapping)
    X["MTRANS"]=X["MTRANS"].map(config.transport_mapping)
    return X

test=test_encode(test_X)
test.dtypes
# Out:
# Gender                              int64
# Age                               float64
# Height                            float64
# Weight                            float64
# family_history_with_overweight      int64
# FAVC                                int64
# FCVC                              float64
# NCP                               float64
# CAEC                                int64
# SMOKE                               int64
# CH2O                              float64
# SCC                                 int64
# FAF                               float64
# TUE                               float64
# CALC                                int64
# MTRANS                              int64
# dtype: object

# %%
add_columns(test)
norm_col(test)
test
# Out:
#        Gender       Age    Height    Weight  family_history_with_overweight  \
# 0         1.0  0.274466  0.751498  0.647675                             1.0
# 1         0.0  0.148936  0.283019  0.214188                             1.0
# 2         0.0  0.255319  0.364821  0.575933                             1.0
# 3         1.0  0.148495  0.194579  0.513014                             1.0
# 4         0.0  0.255319  0.334709  0.522265                             1.0
# ...       ...       ...       ...       ...                             ...
# 13835     1.0  0.198465  0.512045  0.309624                             1.0
# 13836     0.0  0.319149  0.264151  0.182457                             0.0
# 13837     0.0  0.190119  0.255749  0.042652                             0.0
# 13838     1.0  0.148936  0.320755  0.111061                             1.0
# 13839     1.0  0.265764  0.683508  0.650343                             1.0
#
#        FAVC      FCVC       NCP      CAEC  SMOKE      CH2O  SCC       FAF  \
# 0       1.0  0.969308  0.666667  0.333333    0.0  0.912815  0.0  0.285133
# 1       1.0  0.500000  0.000000  0.333333    0.0  1.000000  0.0  0.333333
# 2       1.0  1.000000  0.666667  0.333333    0.0  0.810939  0.0  0.000000
# 3       1.0  0.500000  0.659303  0.333333    0.0  0.893209  0.0  0.031617
# 4       1.0  1.000000  0.666667  0.333333    0.0  0.826766  0.0  0.000000
# ...     ...       ...       ...       ...    ...       ...  ...       ...
# 13835   0.0  0.906617  0.666667  0.333333    0.0  0.000000  0.0  0.269025
# 13836   1.0  1.000000  0.666667  0.333333    0.0  0.500000  0.0  0.000000
# 13837   1.0  1.000000  0.424580  0.666667    0.0  0.500000  0.0  0.649947
# 13838   1.0  0.500000  0.666667  0.333333    0.0  0.500000  0.0  1.000000
# 13839   1.0  0.872497  0.666667  0.333333    0.0  0.602988  0.0  0.434764
#
#             TUE      CALC  MTRANS       BMI   all_eat    Active
# 0      0.000000  0.333333     0.5  0.585777  0.500000  0.338850
# 1      0.000000  0.333333     0.5  0.337588  0.166667  0.375000
# 2      0.125251  0.333333     0.5  0.742193  0.500000  0.125000
# 3      0.000000  0.333333     0.5  0.785219  0.496318  0.148713
# 4      0.370534  0.333333     0.5  0.696899  0.500000  0.125000
# ...         ...       ...     ...       ...       ...       ...
# 13835  0.389316  0.333333     0.5  0.351964  0.500000  0.326769
# 13836  0.000000  0.333333     0.5  0.304869  0.500000  0.125000
# 13837  0.500000  0.333333     0.5  0.125974  0.545623  0.612460
# 13838  1.000000  0.000000     0.5  0.192172  0.500000  0.875000
# 13839  0.315433  0.333333     0.5  0.625366  0.500000  0.451073
#
# [13840 rows x 19 columns]

# %%
test=test.astype(float)
column_X=test.columns
test.dtypes
# Out:
# Gender                            float64
# Age                               float64
# Height                            float64
# Weight                            float64
# family_history_with_overweight    float64
# FAVC                              float64
# FCVC                              float64
# NCP                               float64
# CAEC                              float64
# SMOKE                             float64
# CH2O                              float64
# SCC                               float64
# FAF                               float64
# TUE                               float64
# CALC                              float64
# MTRANS                            float64
# BMI                               float64
# all_eat                           float64
# Active                            float64
# dtype: object

# %%
test_X=torch.FloatTensor(np.array(test)).to(config.device)

# %%
device=config.device

best_model=Model(config.input_class,config.output_class,636,284,112,0.3).to(device)

optimizer=Adam(best_model.parameters(),lr=0.0007731137492224833)

epochs=config.epochs
for step in range(epochs):
    train(best_model,device,train_dataloader,optimizer)
    error_rate=valid(best_model,device,valid_dataloader)
print(error_rate)
# Out:
# 0.11687458962573871

# %%
pred=best_model(test_X)
pred
# Out:
# tensor([[  2.2339, -14.8132,  -9.4430,  ...,  14.3302,  -3.8712,   6.4218],
#         [  2.7207,  -0.1110,  -4.7837,  ...,  -8.1958,   6.7587,   3.0382],
#         [ -5.1905,  -4.9477,  -7.4833,  ...,  -1.0531,  -7.0127,   5.6393],
#         ...,
#         [ -3.4481,   7.9870,  11.9544,  ..., -16.4286,   2.5263,  -4.3565],
#         [ -1.8276,   8.3403,   8.0257,  ..., -15.1817,   2.0622,  -2.3249],
#         [  3.4176, -15.9907, -10.3452,  ...,  15.3856,  -4.1525,   6.7995]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)

# %%
pred_class=torch.argmax(pred,dim=1).cpu()
print(pred_class)
final_output=pd.concat([pd.DataFrame(config.test["id"]),pd.DataFrame(pred_class)],axis=1)
final_output.rename(columns={0:"NObeyesdad"},inplace=True)
final_output.head()
final_output
# Out:
# tensor([4, 5, 3,  ..., 2, 1, 4])
#           id  NObeyesdad
# 0      20758           4
# 1      20759           5
# 2      20760           3
# 3      20761           6
# 4      20762           3
# ...      ...         ...
# 13835  34593           0
# 13836  34594           1
# 13837  34595           2
# 13838  34596           1
# 13839  34597           4
#
# [13840 rows x 2 columns]

# %%
class_mapping_rev = {config.class_mapping[k] : k for k in config.class_mapping}
class_mapping_rev
# Out:
# {0: 'Overweight_Level_II',
#  1: 'Normal_Weight',
#  2: 'Insufficient_Weight',
#  3: 'Obesity_Type_III',
#  4: 'Obesity_Type_II',
#  5: 'Overweight_Level_I',
#  6: 'Obesity_Type_I'}

# %%
final_output['NObeyesdad'] = final_output['NObeyesdad'].map(class_mapping_rev)
final_output
# Out:
#           id           NObeyesdad
# 0      20758      Obesity_Type_II
# 1      20759   Overweight_Level_I
# 2      20760     Obesity_Type_III
# 3      20761       Obesity_Type_I
# 4      20762     Obesity_Type_III
# ...      ...                  ...
# 13835  34593  Overweight_Level_II
# 13836  34594        Normal_Weight
# 13837  34595  Insufficient_Weight
# 13838  34596        Normal_Weight
# 13839  34597      Obesity_Type_II
#
# [13840 rows x 2 columns]

# %%
final_output.to_csv('submission.csv', index=False)
